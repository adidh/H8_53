# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
df = pd.read_csv("nbaallelo.csv")

# %%
num_rows, num_cols=df.shape
print("num of rows:", num_rows)
print("num of columns:", num_cols)
# Out:
# num of rows: 126314
# num of columns: 23

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
with pd.option_context("display.max.columns", None):
    display(df.head())
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.head(15)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# ...

# %%
df.tail(15)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126299      63150  201505260CLE   NBA        1     2015  5/26/2015
# 126300      63151  201505270GSW   NBA        1     2015  5/27/2015
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126302      63152  201506040GSW   NBA        1     2015   6/4/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df.describe(include="object") #object saja
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     201311130BOS     NBA  4/17/2013     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                A           L  at New York NY
# freq           63138       63157             440

# %%
df.describe(exclude="number") #number saja
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     201311130BOS     NBA  4/17/2013     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                A           L  at New York NY
# freq           63138       63157             440

# %%
df.describe(include="all").T #untuk transpose
# Out:
#                 count unique             top    freq       mean       std  \
# gameorder      126314    NaN             NaN     NaN      31579   18231.9
# game_id        126314  63157    201311130BOS       2        NaN       NaN
# lg_id          126314      2             NBA  118016        NaN       NaN
# _iscopy        126314    NaN             NaN     NaN        0.5  0.500002
# year_id        126314    NaN             NaN     NaN     1988.2   17.5823
# date_game      126314  12426       4/17/2013      30        NaN       NaN
# seasongame     126314    NaN             NaN     NaN    43.5337   25.3752
# is_playoffs    126314    NaN             NaN     NaN  0.0638567  0.244499
# team_id        126314    104             BOS    5997        NaN       NaN
# fran_id        126314     53          Lakers    6024        NaN       NaN
# pts            126314    NaN             NaN     NaN     102.73   14.8148
# elo_i          126314    NaN             NaN     NaN    1495.24    112.14
# ...

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# INJ      60
# DTF      60
# PIT      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gameorder          int64
# game_id           object
# lg_id             object
# _iscopy            int64
# year_id            int64
# date_game         object
# seasongame         int64
# is_playoffs        int64
# team_id           object
# fran_id           object
# pts                int64
# elo_i            float64
# elo_n            float64
# win_equiv        float64
# opp_id            object
# opp_fran          object
# opp_pts            int64
# opp_elo_i        float64
# opp_elo_n        float64
# game_location     object
# game_result       object
# forecast         float64
# notes             object
# dtype: object

# %%
revenues = pd.Series([5555, 7000,1980])
print(revenues)
print(type(revenues))
print(revenues.dtypes)
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64
# <class 'pandas.core.series.Series'>
# int64

# %%
print("index:", revenues.index)
# Out:
# index: RangeIndex(start=0, stop=3, step=1)

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500], 
    index=["Surabaya", "Jakarta", "Bandung"],
    name="income"
)
print(city_revenues)
# Out:
# Surabaya    4200
# Jakarta     8000
# Bandung     6500
# Name: income, dtype: int64

# %%
another_revenues = pd.Series(
    {"Surabaya":4200, "Jakarta":8000, "Bandung": 6500},
    name="revenues"
)
print(another_revenues)
# Out:
# Surabaya    4200
# Jakarta     8000
# Bandung     6500
# Name: revenues, dtype: int64

# %% [markdown]
# DataFrame

# %%
manual_df = pd.DataFrame(
    [[5, 1000], [8,1500]],
    index=["amsterdam", "tokyo"],
    columns=["employee_count", "revenue"]
)
manual_df
# Out:
#            employee_count  revenue
# amsterdam               5     1000
# tokyo                   8     1500

# %%
manual_df["employee_count"]
# Out:
# amsterdam    5
# tokyo        8
# Name: employee_count, dtype: int64

# %%
pd.DataFrame(
    {
        "revenues": revenues,
        "another_revenues": city_revenues
    }
)
# Out:
#           revenues  another_revenues
# 0           5555.0               NaN
# 1           7000.0               NaN
# 2           1980.0               NaN
# Bandung        NaN            6500.0
# Jakarta        NaN            8000.0
# Surabaya       NaN            4200.0

# %%
df.head
# Out:
# <bound method NDFrame.head of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df["year_id"].value_counts()
# Out:
# 2014    2638
# 2006    2638
# 2008    2632
# 2009    2630
# 2013    2628
#         ...
# 1959     620
# 1955     618
# 1958     618
# 1957     614
# 1948     430
# Name: year_id, Length: 69, dtype: int64

# %%
df["year_id"].nunique()
# Out:
# 69

# %%
df["year_id"].unique()
# Out:
# array([1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015], dtype=int64)

# %%
df["year_id"].value_counts().index
# Out:
# Int64Index([2014, 2006, 2008, 2009, 2013, 2005, 2010, 2011, 2015, 2007, 2003,
#             2004, 2000, 1997, 1998, 2001, 2002, 1996, 1975, 1971, 1972, 1973,
#             1974, 1994, 1993, 1995, 1992, 1990, 1991, 1976, 1970, 1989, 1969,
#             2012, 1988, 1984, 1987, 1985, 1986, 1981, 1968, 1982, 1983, 1979,
#             1977, 1978, 1980, 1999, 1950, 1967, 1962, 1963, 1964, 1966, 1965,
#             1949, 1951, 1953, 1952, 1947, 1954, 1961, 1960, 1956, 1959, 1955,
#             1958, 1957, 1948],
#            dtype='int64')

# %%
df.fran_id
# Out:
# 0           Huskies
# 1            Knicks
# 2             Stags
# 3            Knicks
# 4           Falcons
#             ...
# 126309    Cavaliers
# 126310     Warriors
# 126311    Cavaliers
# 126312    Cavaliers
# 126313     Warriors
# Name: fran_id, Length: 126314, dtype: object

# %%
df[["year_id", "team_id", "opp_id", "game_result"]]
# Out:
#         year_id team_id opp_id game_result
# 0          1947     TRH    NYK           L
# 1          1947     NYK    TRH           W
# 2          1947     CHS    NYK           W
# 3          1947     NYK    CHS           L
# 4          1947     DTF    WSC           L
# ...         ...     ...    ...         ...
# 126309     2015     CLE    GSW           L
# 126310     2015     GSW    CLE           W
# 126311     2015     CLE    GSW           L
# 126312     2015     CLE    GSW           L
# 126313     2015     GSW    CLE           W
#
# [126314 rows x 4 columns]

# %%
summary_cols = ["year_id", "team_id", "opp_id", "pts", "opp_pts", "game_result"]
df_summary = df[summary_cols]
df_summary
# Out:
#         year_id team_id opp_id  pts  opp_pts game_result
# 0          1947     TRH    NYK   66       68           L
# 1          1947     NYK    TRH   68       66           W
# 2          1947     CHS    NYK   63       47           W
# 3          1947     NYK    CHS   47       63           L
# 4          1947     DTF    WSC   33       50           L
# ...         ...     ...    ...  ...      ...         ...
# 126309     2015     CLE    GSW   82      103           L
# 126310     2015     GSW    CLE  104       91           W
# 126311     2015     CLE    GSW   91      104           L
# 126312     2015     CLE    GSW   97      105           L
# 126313     2015     GSW    CLE  105       97           W
#
# [126314 rows x 6 columns]

# %%
df_summary.loc[:5, ["pts"]]
# Out:
#    pts
# 0   66
# 1   68
# 2   63
# 3   47
# 4   33
# 5   50

# %%
df_summary.loc[:5]
# Out:
#    year_id team_id opp_id  pts game_result
# 0     1947     TRH    NYK   66           L
# 1     1947     NYK    TRH   68           W
# 2     1947     CHS    NYK   63           W
# 3     1947     NYK    CHS   47           L
# 4     1947     DTF    WSC   33           L
# 5     1947     WSC    DTF   50           W

# %%
df_summary["team_id"] == "GSW"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310     True
# 126311    False
# 126312    False
# 126313     True
# Name: team_id, Length: 126314, dtype: bool

# %%
df_summary[df_summary["team_id"] == "GSW"]
# Out:
#         year_id team_id opp_id  pts game_result
# 24045      1972     GSW    BOS   97           W
# 24064      1972     GSW    BAL   93           L
# 24099      1972     GSW    NYK   84           L
# 24112      1972     GSW    CLE  115           W
# 24155      1972     GSW    DET  115           W
# ...         ...     ...    ...  ...         ...
# 126305     2015     GSW    CLE   93           L
# 126306     2015     GSW    CLE   91           L
# 126308     2015     GSW    CLE  103           W
# 126310     2015     GSW    CLE  104           W
# 126313     2015     GSW    CLE  105           W
#
# [3701 rows x 5 columns]

# %%
df_gsw_win = df_summary[
    (df_summary["team_id"] == "GSW")
    & (df_summary.pts > df_summary.opp_pts)
]

# %%
df_gsw_win["opp_id"].value_counts()
# Out:
# POR    91
# PHO    86
# SEA    80
# LAC    80
# LAL    77
# DEN    75
# HOU    74
# DAL    70
# UTA    66
# SAC    65
# DET    60
# SAS    58
# PHI    57
# MIN    57
# CLE    55
# NYK    55
# ATL    54
# MIL    50
# CHI    50
# BOS    45
# NJN    39
# IND    38
# WSB    33
# KCK    28
# MIA    26
# MEM    25
# ORL    22
# TOR    22
# BUF    20
# WAS    19
# SDC    17
# VAN    15
# NOH    14
# CHH    12
# NOP    10
# KCO     9
# CHA     9
# OKC     9
# NOJ     8
# BAL     5
# BRK     4
# NOK     4
# NYN     3
# CIN     3
# CHO     2
# CAP     1
# Name: opp_id, dtype: int64

# %%
df_summary[df_summary.year_id >= 2005]
# Out:
#         year_id team_id opp_id  pts  opp_pts game_result
# 97886      2005     SAC    DAL   98      107           L
# 97887      2005     DAL    SAC  107       98           W
# 97888      2005     HOU    DET   79       87           L
# 97889      2005     DET    HOU   87       79           W
# 97890      2005     LAL    DEN   89       78           W
# ...         ...     ...    ...  ...      ...         ...
# 126309     2015     CLE    GSW   82      103           L
# 126310     2015     GSW    CLE  104       91           W
# 126311     2015     CLE    GSW   91      104           L
# 126312     2015     CLE    GSW   97      105           L
# 126313     2015     GSW    CLE  105       97           W
#
# [28428 rows x 6 columns]

# %%
df_summary[
    (df_summary.year_id >= 2005)
    & (df_summary.pts > df_summary.opp_pts)
]
# Out:
#         year_id team_id opp_id  pts  opp_pts game_result
# 97887      2005     DAL    SAC  107       98           W
# 97889      2005     DET    HOU   87       79           W
# 97890      2005     LAL    DEN   89       78           W
# 97893      2005     PHI    BOS   98       95           W
# 97895      2005     IND    CLE  109      104           W
# ...         ...     ...    ...  ...      ...         ...
# 126304     2015     CLE    GSW   95       93           W
# 126307     2015     CLE    GSW   96       91           W
# 126308     2015     GSW    CLE  103       82           W
# 126310     2015     GSW    CLE  104       91           W
# 126313     2015     GSW    CLE  105       97           W
#
# [14214 rows x 6 columns]

# %%
df_summary[
    (df_summary.year_id >= 2005)
    & (df_summary.pts > df_summary.opp_pts)
]["team_id"]
# Out:
# 97887     DAL
# 97889     DET
# 97890     LAL
# 97893     PHI
# 97895     IND
#          ...
# 126304    CLE
# 126307    CLE
# 126308    GSW
# 126310    GSW
# 126313    GSW
# Name: team_id, Length: 14214, dtype: object

# %%
df_summary.loc[
    (df_summary.year_id >= 2005)
    & (df_summary.pts > df_summary.opp_pts),
    "team_id"
].value_counts()
# Out:
# SAS    725
# DAL    624
# MIA    611
# PHO    553
# LAL    550
# HOU    547
# CHI    544
# BOS    540
# DEN    527
# CLE    520
# DET    486
# IND    482
# MEM    477
# UTA    474
# ORL    470
# GSW    467
# ATL    464
# LAC    462
# POR    451
# TOR    403
# WAS    398
# PHI    384
# OKC    378
# MIL    370
# NYK    366
# SAC    341
# MIN    300
# CHA    293
# NJN    269
# NOH    264
# SEA    144
# BRK    141
# NOP     79
# NOK     77
# CHO     33
# Name: team_id, dtype: int64

# %%
df_summary.loc[
    (df_summary.year_id >= 2005)
    & (df_summary.pts > df_summary.opp_pts),
    "team_id"
]
# Out:
# 97887     DAL
# 97889     DET
# 97890     LAL
# 97893     PHI
# 97895     IND
#          ...
# 126304    CLE
# 126307    CLE
# 126308    GSW
# 126310    GSW
# 126313    GSW
# Name: team_id, Length: 14214, dtype: object

# %%
df["team_id"].str.startswith("LA") #--> tetap object
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: team_id, Length: 126314, dtype: bool

# %%
df["team_id"].astype("string").str.startswith("LA")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: team_id, Length: 126314, dtype: boolean

# %%
df.loc[
    df["team_id"].str.startswith("LA"),
    "team_id"
].unique()
# Out:
# array(['LAL', 'LAS', 'LAC'], dtype=object)

# %%
df.loc[
    (df["fran_id"] == "Stars") & (df["team_id"].str.startswith("LA")),
    ["year_id", "team_id", "fran_id"]
]
# Out:
#        year_id team_id fran_id
# 17266     1969     LAS   Stars
# 17276     1969     LAS   Stars
# 17303     1969     LAS   Stars
# 17343     1969     LAS   Stars
# 17376     1969     LAS   Stars
# ...        ...     ...     ...
# 21538     1970     LAS   Stars
# 21540     1970     LAS   Stars
# 21543     1970     LAS   Stars
# 21544     1970     LAS   Stars
# 21546     1970     LAS   Stars
#
# [179 rows x 3 columns]

# %%
df_gsw_win.sort_values(["pts", "opp_pts"], ascending=False)
# Out:
#        year_id team_id opp_id  pts  opp_pts game_result
# 64288     1991     GSW    DEN  162      158           W
# 61146     1989     GSW    SAC  155      143           W
# 50356     1984     GSW    SAS  154      133           W
# 68535     1992     GSW    NJN  153      148           W
# 66663     1992     GSW    SAC  153       91           W
# ...        ...     ...    ...  ...      ...         ...
# 84550     1999     GSW    LAL   81       76           W
# 81887     1998     GSW    DEN   81       69           W
# 86824     2000     GSW    ATL   80       75           W
# 95708     2004     GSW    POR   78       72           W
# 74644     1995     GSW    DEN   77       73           W
#
# [1702 rows x 6 columns]

# %%
df_gsw_win.sort_values(["pts", "opp_pts"], ascending=True)
# Out:
#        year_id team_id opp_id  pts  opp_pts game_result
# 74644     1995     GSW    DEN   77       73           W
# 95708     2004     GSW    POR   78       72           W
# 86824     2000     GSW    ATL   80       75           W
# 81887     1998     GSW    DEN   81       69           W
# 84550     1999     GSW    LAL   81       76           W
# ...        ...     ...    ...  ...      ...         ...
# 66663     1992     GSW    SAC  153       91           W
# 68535     1992     GSW    NJN  153      148           W
# 50356     1984     GSW    SAS  154      133           W
# 61146     1989     GSW    SAC  155      143           W
# 64288     1991     GSW    DEN  162      158           W
#
# [1702 rows x 6 columns]

# %%
df.groupby("fran_id")["pts"].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...
